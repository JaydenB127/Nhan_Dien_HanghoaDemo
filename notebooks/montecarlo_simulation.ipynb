# %% [markdown]
# # Monte Carlo SimulationUse this notebook to experiment with different demand distributions and visualise the effect on shortage/overstock probabilities.

# %%
# Placeholder
# Replace this cell with data loading, training, and visualisation code.
