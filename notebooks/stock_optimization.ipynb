# %% [markdown]
# # Stock OptimisationPrototype the machine-learning pipeline that recommends reorder quantities and safety stock levels.

# %%
# Placeholder
# Replace this cell with data loading, training, and visualisation code.
